# %% [markdown]
# # File with the scaler used to transform the data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
from scipy import stats
from scipy.stats import pearsonr

warnings.filterwarnings('ignore')

# %%
# !pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\usuario\anaconda3\lib\site-packages (2.5.1.post0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (0.24.2)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (1.3.4)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (0.5.2)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (1.20.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from category_encoders) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\usuario\anaconda3\lib\site-packages (from pandas>=1.0.5->category_encoders) (2021.3)
# Requirement already satisfied: six in c:\users\usuario\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.16.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\usuario\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.2.0)

# %%
#We import the category_encoders library to encode the categorical data.
#This is converting them to integer format so they can be provided to the model.
import category_encoders as ce

# %%
ccm= pd.read_excel('creditcardmarketing.xlsx')

# %%
ccm.head(10)
# Out:
#    Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                1             No  Air Miles      Letter         High
# 1                2             No  Air Miles      Letter       Medium
# 2                3             No  Air Miles    Postcard         High
# 3                4             No  Air Miles      Letter       Medium
# 4                5             No  Air Miles      Letter       Medium
# 5                6             No  Air Miles      Letter       Medium
# 6                7             No  Air Miles      Letter       Medium
# 7                8             No  Cash Back    Postcard          Low
# 8                9             No  Air Miles    Postcard       Medium
# 9               10             No  Air Miles      Letter         High
#
#    # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                     1                   No          High
# 1                     1                   No        Medium
# 2                     2                   No        Medium
# 3                     2                   No          High
# 4                     1                   No        Medium
# 5                     1                   No          High
# 6                     1                   No        Medium
# 7                     1                   No        Medium
# 8                     1                   No           Low
# 9                     2                   No           Low
#
#    # Credit Cards Held  # Homes Owned  Household Size Own Your Home  \
# 0                    2              1               4            No
# 1                    2              2               5           Yes
# 2                    2              1               2           Yes
# 3                    1              1               4            No
# 4                    2              1               6           Yes
# 5                    3              1               4            No
# 6                    2              1               3            No
# 7                    4              1               4           Yes
# 8                    2              1               4           Yes
# 9                    3              2               4           Yes
#
#    Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  Q4 Balance
# 0          1160.75      1669.0       877.0      1095.0      1002.0
# 1           147.25        39.0       106.0        78.0       366.0
# 2           276.50       367.0       352.0       145.0       242.0
# 3          1219.00      1578.0      1760.0      1119.0       419.0
# 4          1211.00      2140.0      1357.0       982.0       365.0
# 5          1114.75      1847.0      1365.0       750.0       497.0
# 6           283.75       468.0       188.0       347.0       132.0
# 7           278.50       132.0       391.0       285.0       306.0
# 8          1005.00       894.0       891.0       882.0      1353.0
# 9           974.25      1814.0      1454.0       514.0       115.0

# %%
encoder= ce.OrdinalEncoder(cols=['Income Level'], return_df=True, mapping=[{'col':'Income Level', 'mapping':{'Low':1, 'Medium':2, 'High':3}}])
ccm['new_income_level'] = encoder.fit_transform(ccm['Income Level'])

# %%
encoder = ce.OrdinalEncoder(cols=['Offer Accepted'], return_df=True, mapping=[{'col':'Offer Accepted', 'mapping':{'No':0, 'Yes':1}}])
ccm['new_offer_accepted'] = encoder.fit_transform(ccm['Offer Accepted'])

# %%
encoder = ce.OrdinalEncoder(cols=['Credit Rating'], return_df=True, mapping=[{'col':'Credit Rating', 'mapping':{'Low':1, 'Medium':2, 'High':3}}])
ccm['new_credit_rating'] = encoder.fit_transform(ccm['Credit Rating'])

# %%
encoder = ce.OrdinalEncoder(cols=['Own Your Home'], return_df=True, mapping=[{'col':'Own Your Home', 'mapping':{'No':0, 'Yes':1}}])
ccm['new_own_your_home'] = encoder.fit_transform(ccm['Own Your Home'])

# %%
encoder = ce.OrdinalEncoder(cols=['Overdraft Protection'], return_df=True, mapping=[{'col':'Overdraft Protection', 'mapping':{'No':0, 'Yes':1}}])
ccm['new_overdraft_protection'] = encoder.fit_transform(ccm['Overdraft Protection'])

# %%
encoder = ce.OrdinalEncoder(cols=['Mailer Type'], return_df=True, mapping=[{'col':'Mailer Type', 'mapping':{'Letter':1, 'Postcard':2, 'Email':3}}])
ccm['new_mailer_type'] = encoder.fit_transform(ccm['Mailer Type'])

# %%
encoder = ce.OrdinalEncoder(cols=['Reward'], return_df=True, mapping=[{'col':'Reward', 'mapping':{'Air Miles':1, 'Cash Back':2, 'Points':3}}])
ccm['new_reward'] = encoder.fit_transform(ccm['Reward'])

# %%
ccm.head(10)
# Out:
#    Customer Number Offer Accepted     Reward Mailer Type Income Level  \
# 0                1             No  Air Miles      Letter         High
# 1                2             No  Air Miles      Letter       Medium
# 2                3             No  Air Miles    Postcard         High
# 3                4             No  Air Miles      Letter       Medium
# 4                5             No  Air Miles      Letter       Medium
# 5                6             No  Air Miles      Letter       Medium
# 6                7             No  Air Miles      Letter       Medium
# 7                8             No  Cash Back    Postcard          Low
# 8                9             No  Air Miles    Postcard       Medium
# 9               10             No  Air Miles      Letter         High
#
#    # Bank Accounts Open Overdraft Protection Credit Rating  \
# 0                     1                   No          High
# 1                     1                   No        Medium
# 2                     2                   No        Medium
# 3                     2                   No          High
# 4                     1                   No        Medium
# 5                     1                   No          High
# 6                     1                   No        Medium
# 7                     1                   No        Medium
# 8                     1                   No           Low
# 9                     2                   No           Low
#
#    # Credit Cards Held  # Homes Owned  ...  Q2 Balance Q3 Balance  Q4 Balance  \
# 0                    2              1  ...       877.0     1095.0      1002.0
# 1                    2              2  ...       106.0       78.0       366.0
# 2                    2              1  ...       352.0      145.0       242.0
# 3                    1              1  ...      1760.0     1119.0       419.0
# 4                    2              1  ...      1357.0      982.0       365.0
# 5                    3              1  ...      1365.0      750.0       497.0
# 6                    2              1  ...       188.0      347.0       132.0
# 7                    4              1  ...       391.0      285.0       306.0
# 8                    2              1  ...       891.0      882.0      1353.0
# 9                    3              2  ...      1454.0      514.0       115.0
#
#    new_income_level  new_offer_accepted  new_credit_rating  new_own_your_home  \
# 0                 3                   0                  3                  0
# 1                 2                   0                  2                  1
# 2                 3                   0                  2                  1
# 3                 2                   0                  3                  0
# 4                 2                   0                  2                  1
# 5                 2                   0                  3                  0
# 6                 2                   0                  2                  0
# 7                 1                   0                  2                  1
# 8                 2                   0                  1                  1
# 9                 3                   0                  1                  1
#
#    new_overdraft_protection  new_mailer_type  new_reward
# 0                         0                1           1
# 1                         0                1           1
# 2                         0                2           1
# 3                         0                1           1
# 4                         0                1           1
# 5                         0                1           1
# 6                         0                1           1
# 7                         0                2           2
# 8                         0                2           1
# 9                         0                1           1
#
# [10 rows x 24 columns]

# %%
ccm =ccm.drop(['Income Level', 'Offer Accepted', 'Credit Rating', 'Own Your Home', 'Overdraft Protection', 'Mailer Type', 'Reward'], axis=1)

# %%
ccm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer Number           18000 non-null  int64
#  1   # Bank Accounts Open      18000 non-null  int64
#  2   # Credit Cards Held       18000 non-null  int64
#  3   # Homes Owned             18000 non-null  int64
#  4   Household Size            18000 non-null  int64
#  5   Average Balance           17976 non-null  float64
#  6   Q1 Balance                17976 non-null  float64
#  7   Q2 Balance                17976 non-null  float64
#  8   Q3 Balance                17976 non-null  float64
#  9   Q4 Balance                17976 non-null  float64
#  10  new_income_level          18000 non-null  int32
#  11  new_offer_accepted        18000 non-null  int32
#  12  new_credit_rating         18000 non-null  int32
#  13  new_own_your_home         18000 non-null  int32
#  14  new_overdraft_protection  18000 non-null  int32
#  15  new_mailer_type           18000 non-null  int32
#  16  new_reward                18000 non-null  int32
# dtypes: float64(5), int32(7), int64(5)
# memory usage: 1.9 MB

# %%
ccm.dropna(inplace=True)

# %% [markdown]
# Check for null values:

# %%
sns.heatmap(ccm.isnull(), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
ccm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17976 entries, 0 to 17999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer Number           17976 non-null  int64
#  1   # Bank Accounts Open      17976 non-null  int64
#  2   # Credit Cards Held       17976 non-null  int64
#  3   # Homes Owned             17976 non-null  int64
#  4   Household Size            17976 non-null  int64
#  5   Average Balance           17976 non-null  float64
#  6   Q1 Balance                17976 non-null  float64
#  7   Q2 Balance                17976 non-null  float64
#  8   Q3 Balance                17976 non-null  float64
#  9   Q4 Balance                17976 non-null  float64
#  10  new_income_level          17976 non-null  int32
#  11  new_offer_accepted        17976 non-null  int32
#  12  new_credit_rating         17976 non-null  int32
#  13  new_own_your_home         17976 non-null  int32
#  14  new_overdraft_protection  17976 non-null  int32
#  15  new_mailer_type           17976 non-null  int32
#  16  new_reward                17976 non-null  int32
# dtypes: float64(5), int32(7), int64(5)
# memory usage: 2.0 MB

# %%
ccm.head(20)
#We have now created the new dataset that we will work with from now on.
# Out:
#     Customer Number  # Bank Accounts Open  # Credit Cards Held  # Homes Owned  \
# 0                 1                     1                    2              1
# 1                 2                     1                    2              2
# 2                 3                     2                    2              1
# 3                 4                     2                    1              1
# 4                 5                     1                    2              1
# 5                 6                     1                    3              1
# 6                 7                     1                    2              1
# 7                 8                     1                    4              1
# 8                 9                     1                    2              1
# 9                10                     2                    3              2
# 10               11                     1                    3              1
# 11               12                     1                    3              2
# 12               13                     1                    1              1
# 13               14                     1                    1              1
# 14               15                     2                    3              1
# 15               16                     1                    2              1
# 16               17                     2                    1              1
# 17               18                     2                    2              1
# 18               19                     1                    1              1
# 19               20                     1                    2              1
#
#     Household Size  Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  \
# 0                4          1160.75      1669.0       877.0      1095.0
# 1                5           147.25        39.0       106.0        78.0
# 2                2           276.50       367.0       352.0       145.0
# 3                4          1219.00      1578.0      1760.0      1119.0
# 4                6          1211.00      2140.0      1357.0       982.0
# 5                4          1114.75      1847.0      1365.0       750.0
# 6                3           283.75       468.0       188.0       347.0
# 7                4           278.50       132.0       391.0       285.0
# 8                4          1005.00       894.0       891.0       882.0
# 9                4           974.25      1814.0      1454.0       514.0
# 10               2          1135.25       762.0       827.0      1454.0
# 11               5          1221.00       551.0      1652.0       896.0
# 12               2          1150.50      1756.0      1402.0       969.0
# 13               3          1052.25      1996.0      1038.0       439.0
# 14               3          1013.25      1819.0       901.0       854.0
# 15               2          1012.25      1715.0      1486.0       713.0
# 16               4          1217.00       567.0      1161.0       966.0
# 17               4          1185.25       272.0      1523.0      2042.0
# 18               4          1059.75      1876.0      1068.0       900.0
# 19               5          1086.75       764.0       997.0       921.0
#
#     Q4 Balance  new_income_level  new_offer_accepted  new_credit_rating  \
# 0       1002.0                 3                   0                  3
# 1        366.0                 2                   0                  2
# 2        242.0                 3                   0                  2
# 3        419.0                 2                   0                  3
# 4        365.0                 2                   0                  2
# 5        497.0                 2                   0                  3
# 6        132.0                 2                   0                  2
# 7        306.0                 1                   0                  2
# 8       1353.0                 2                   0                  1
# 9        115.0                 3                   0                  1
# 10      1498.0                 2                   0                  2
# 11      1785.0                 3                   0                  2
# 12       475.0                 2                   0                  1
# 13       736.0                 1                   0                  3
# 14       479.0                 1                   0                  3
# 15       135.0                 3                   0                  1
# 16      2174.0                 1                   0                  2
# 17       904.0                 1                   0                  3
# 18       395.0                 2                   0                  1
# 19      1665.0                 2                   0                  3
#
#     new_own_your_home  new_overdraft_protection  new_mailer_type  new_reward
# 0                   0                         0                1           1
# 1                   1                         0                1           1
# 2                   1                         0                2           1
# 3                   0                         0                1           1
# 4                   1                         0                1           1
# 5                   0                         0                1           1
# 6                   0                         0                1           1
# 7                   1                         0                2           2
# 8                   1                         0                2           1
# 9                   1                         0                1           1
# 10                  1                         0                2           1
# 11                  1                         0                2           2
# 12                  1                         0                1           3
# 13                  0                         0                1           3
# 14                  1                         0                1           1
# 15                  0                         0                1           2
# 16                  1                         0                2           3
# 17                  1                         0                2           1
# 18                  0                         0                2           3
# 19                  1                         0                1           2

# %%
ccm.to_csv('nuevo_ccm.csv', index = False)

# %%
pd.read_csv('nuevo_ccm.csv').head()
# Out:
#    Customer Number  # Bank Accounts Open  # Credit Cards Held  # Homes Owned  \
# 0                1                     1                    2              1
# 1                2                     1                    2              2
# 2                3                     2                    2              1
# 3                4                     2                    1              1
# 4                5                     1                    2              1
#
#    Household Size  Average Balance  Q1 Balance  Q2 Balance  Q3 Balance  \
# 0               4          1160.75      1669.0       877.0      1095.0
# 1               5           147.25        39.0       106.0        78.0
# 2               2           276.50       367.0       352.0       145.0
# 3               4          1219.00      1578.0      1760.0      1119.0
# 4               6          1211.00      2140.0      1357.0       982.0
#
#    Q4 Balance  new_income_level  new_offer_accepted  new_credit_rating  \
# 0      1002.0                 3                   0                  3
# 1       366.0                 2                   0                  2
# 2       242.0                 3                   0                  2
# 3       419.0                 2                   0                  3
# 4       365.0                 2                   0                  2
#
#    new_own_your_home  new_overdraft_protection  new_mailer_type  new_reward
# 0                  0                         0                1           1
# 1                  1                         0                1           1
# 2                  1                         0                2           1
# 3                  0                         0                1           1
# 4                  1                         0                1           1
